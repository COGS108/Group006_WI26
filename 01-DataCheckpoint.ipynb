# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# ## Authors
#
# - Candice Tang: Conceptualization, Background Research
# - Carter Cameron: Background Research, Writing - review & editing
# - Owen Canoy: Analysis, Software, Writing - original draft
# - Reece Capers: Ethics
# - Yunjia Xing: Data Curation - original draft

# %% [markdown]
# ## Research Question

# %% [markdown]
# How does the state-level median household income affect the academic performance (numerical average grades) for 8th grade students across the United States during 2018 - 2019 (before COVID-19 pandemic)?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Disparities in academic performance amongst students have long been attributed to differences in socioeconomic status among American students. Since the transition from middle school to high school marks the first step to adulthood, we want to look at the the academic performance for 8th graders and compare it to the socioeconmic status of their household. It is most often believed that students that perfrom well during 8th grade, tend to continue to perform well in highschool and further. Seeing as 8th grade has public testing and more accessible data, we will choose to analyze the relationship between socioeconomic status and academic performance within 8th graders.
#
# A similar yet older study by The American Physiological Association analyzed the relationship between socioeconomic status and education. This study deemed, “Individuals within the top family income quartile are 8 times more likely to obtain a bachelor’s degree by age 24 as compared to individuals from the lowest family income quartile”<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2).
#
# According to the National Assessment of Educational Progress (NAEP), 9 years old and 13 years old students in the United States have an increase in average scores for NAEP long-term trend (LTT) reading and mathematics assessments from 2018-2019 <a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3). Meanwhile, with the rise of academic performance, the data from the United States Census Bureau has informed us that there is a 6.8 percent increase (from 64,323 to 68,703 dollars) in household income in the United States <a name="cite_ref-7"></a>[<sup>7</sup>](#cite_note-7).
#
# Maria N. Wodarz, Natalia L. Komarova and Timmy Ma had done research for the relationship of English Language Arts (ELA) and Mathematics performance scores in 3rd and 8th grades and the median household income from during the 2018-2019 school year. The research found out, in half of the states, there is a linear correlation between academic performance and household income, and the other half characterized by a saturating function. The results reveal that less affluent states exhibit a steeper increase in performance with income compared to wealthier states <a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1).
#
# With the inquiry of the relationship between median household income and academic performance in 3rd and 8th grades, it is important to focus specifically on 8th grade students, as this stage represents a major academic and developmental transition. During 8th grade, students are preparing to enter high school, and their academic achievement can influence placement into advanced courses, access to academic resources, and long-term educational opportunities. By analyzing this relationship, this research can help identify whether economic differences between states are strongly associated with measurable gaps in academic performance.
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Wodarz, Maria N., et al. “The Functional Form of the Association between K-12 Student Performance and Household Income in U.S. School Districts.” PLOS ONE, Public Library of Science, 10 Sept. 2025, journals.plos.org/plosone/article?id=10.1371%2Fjournal.pone.0329296.
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) “Education and Socioeconomic Status.” American Psychological Association, American Psychological Association, 2017, www.apa.org/pi/ses/resources/publications/education.
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) “NAEP Long-Term Trend Assessment Results:Reading and Mathematics.” The Nation’s Report Card, 2023, www.nationsreportcard.gov/ltt/?age=9.
# 3. <a name="cite_note-4"></a> [^](#cite_ref-4) Semega, Jessica. “Income and Poverty in the United States: 2019.” Census.Gov, 9 June 2022, www.census.gov/library/publications/2020/demo/p60-270.html.

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# There is a positive correlation between state-level median household income and academic performance (average grades) among U.S. 8th grade students during 2018-2019, such that states with higher median household income tend to have higher average student grades. We believe that higher household income means access to better academic resources and financial improvement shapes students self-confidence, therefore, with the increase of household income, students would have a better academic performance. We also believe that students that test better in 8th grade tend to have better academic success in high school.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# #### Dataset 1: SEDA (Stanford Education Data Archive) Administrative District Test Score Dataset (version 5.0)
# - Dataset Name: seda_admindist_long_gcs.csv
# - Link to Dataset: https://stacks.stanford.edu/file/druid:cs829jn7849/seda_admindist_long_gcs_5.0_updated_20240319.csv
# - Number of Observations: 1,048,575
# - Number of Variables: 56
# - Description of Variables:
#     - stateabb - state abbreviation, which can be used in state-level comparison year: academic year, including years between 2009 and 2018 (inclusive), can be used to filter out year 2018 to 2019.
#     - grade - grade level, from grade 3 to grade 8. We are including grade 8 instead of senior high school students.
#     - subject - the subject that the students are studying. It can be used to group students and compare their academic performance.
#     - tot_asmt_all - the total number of students assessed. It is the sample size of different districts.
#     - gcs_mn_all: the mean GCS score for students. This is the dependent variable that represents academic performance.
#     - gcs_mn_ecd: the mean score for economically disadvantaged students.
#     - gcs_mn_nec: the mean score for non-economically disadvantaged students.
#         - The above variables will help filter between 2018-2019, exclusively 8th grade, and compare scores based on income levels.
# - Description of Shortcomings:
#     - The income data is not included. This dataset only includes students’ academic performance, and divides the students into economically disadvantaged students and non_economically disadvantaged students. There are missing values in the variables related to our project. For example, gcs_mn_ecd and gcs_mn_nec.
#
# #### Dataset 2: SEDA (Stanford Education Data Archive) Administrative Disctrict Covariates Dataset (version 5.0)
# - Dataset Name: seda_cov_admindist_long_5.0*
# - Link to Dataset: https://stacks.stanford.edu/file/druid:cs829jn7849/seda_cov_admindist_long_5.0_updated_20240319.csv
# - Number of Observations: 1,000,000
# - Number of Variables: 73
# - Description of Variables:
#     - lninc50all: log of median income, eb estimate, all families, time-varying. This represents the log-transformed median household income (median income across families). This is the closest match to state-level median household income in the dataset.
#     - povertyall: poverty rate, eb estimate, all families, time-varying. This represent the overall poverty rate. This is another variable which we could consider to determine the relationship between academic performance and household income.
#     - year and grade: These two variables ensure you are analyzing 8th graders in the 2018–2019 school year.
#     - urbanicity: urbanicity locale (based on student enrollment).This could be considered as one of the factors affecting the household income.
#     - fips and stateabb: These allow you to group by state to create state-level averages.
#     - There are also income and poverty data for different racial which could also be considered while analyzing.
# - Description of Shortcomings:
#     - The data is aggregated at the district level, not individual-level student data.
#     - Many variables came from ACS,  some values may be produced using modeling or smoothing methods (such as “EB estimates,” empirical Bayes).
#
# How do we plan on combing these?
# - We plan on combining these by using school district id's (sedaadmin). This will allow us to match up the scores of the 8th graders and the socioeconmic status that their school districts fall under.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://stacks.stanford.edu/file/druid:cs829jn7849/seda_admindist_long_gcs_5.0_updated_20240319.csv', 'filename':'seda_admindist_long_gcs_5.0_updated_20240319.csv'},
    { 'url': 'https://stacks.stanford.edu/file/druid:cs829jn7849/seda_cov_admindist_long_5.0_updated_20240319.csv', 'filename':'seda_cov_admindist_long_5.0_updated_20240319.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Overall Download Progress:  50%|█████     | 1/2 [00:31<00:31, 31.11s/it]
# Successfully downloaded: seda_admindist_long_gcs_5.0_updated_20240319.csv
# ...
# Overall Download Progress: 100%|██████████| 2/2 [01:03<00:00, 31.99s/it]
# Successfully downloaded: seda_cov_admindist_long_5.0_updated_20240319.csv

# %% [markdown]
# ### 8th Grader Test Performance from 2018-2019 based on Socioeconomic Status
#
# This wrangled dataset contains only 8th graders from the SEDA Administrative District Test Score Dataset (5.0) and its Covariant set combined into one. It has been filtered down to only include 8th graders, our grade scope for this project, as well as only 2018 and 2019 students. The name of the school district tells us which school each data point belongs to, and subject tells whether the test was about math or reading and language.
#
# - Year: Shows either 2018–2019 school year.
# - Mean GCS Score: The mean GCS score for students. This is the dependent variable that represents academic performance. Higher is better, lower is worse.
# - Mean GCS Score for Economically Disadvantaged: The mean score for economically disadvantaged students.
# - Mean GCS Score for Non-Economically Disadvantaged: The mean score for non-economically disadvantaged students. Note that this is on average higher than the disadvantaged students.
# - Median Household Income (Log): Log of median income, eb estimate, all families, time-varying. This represents the log-transformed median household income (median income across families). This is the closest match to state-level median household income in the dataset.
# - Overall Poverty Rate: poverty rate, eb estimate, all families, time-varying. This represent the overall poverty rate. This is another variable which we could consider to determine the relationship between academic performance and household income.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import both datasets into Pandas
df = pd.read_csv("data/00-raw/seda_admindist_long_gcs_5.0_updated_20240319.csv")
cov_df = pd.read_csv("data/00-raw/seda_cov_admindist_long_5.0_updated_20240319.csv",low_memory=False)

#Merge both using the identification of SEDA Admin IDs, year, and grade.
merged_df = df.merge(cov_df, on=["sedaadmin", "year", "grade"], how="left")

#Pandas automatically merging similar columns creates x and y versions. We only need one, so we will drop the X version and keep the Y version from the covariates due to that dataset being more telling of socieoeconomic state.
merged_df = merged_df.drop(columns=["stateabb_x","sedaadminname_x","fips_x"])
merged_df = merged_df.rename(columns={"stateabb_y": "stateabb","sedaadminname_y":"sedaadminname","fips_y":"fips"})

#Print size of dataset:
print("Size of Dataset: ")
print(merged_df.shape)

#Keep only values with valid achievement, removing NaNs in that column
merged_df = merged_df.dropna(subset=["gcs_mn_all"])

#Filter to grade 8 and years 2018/2019. 
merged_df = merged_df[(merged_df["grade"] == 8)]
filtered_df = merged_df[(merged_df["year"] == 2018 )|( merged_df["year"] == 2019)]

#Wrangled data with appropriate columns
soc_df = filtered_df[['sedaadminname','year','subject','gcs_mn_all','gcs_mn_ecd','gcs_mn_nec','lninc50all','povertyall']]
soc_df = soc_df.rename(columns={"sedaadminname": "School District","year":"Year","subject":"Subject","gcs_mn_all":"Mean GCS Score","gcs_mn_ecd":"Mean GCS Score for Economically Disadvantaged","gcs_mn_nec":"Mean GCS Score for Non-Economically Disadvantaged",'lninc50all':'Median Household Income (Log)','povertyall':'Overall Poverty Rate'})

print(soc_df.head())

#TODO: Sort by different categories, look for outliers, fully clean data
# Out:
# Size of Dataset:
# (1410327, 149)
#       School District  Year Subject  Mean GCS Score  \
# 133  Albertville City  2018     mth        7.234210
# 134  Albertville City  2018     rla        7.272912
# 135  Albertville City  2019     mth        7.165455
# 136  Albertville City  2019     rla        6.591630
# 265   Marshall County  2018     mth        6.244147
#
#      Mean GCS Score for Economically Disadvantaged  \
# 133                                       6.380804
# 134                                       6.085680
# 135                                       5.932869
# 136                                       4.988717
# 265                                       5.703243
#
#      Mean GCS Score for Non-Economically Disadvantaged  \
# 133                                           7.696515
# 134                                           8.042640
# 135                                           7.935712
# 136                                           7.437912
# ...

# %% [markdown]
# ## Ethics

# %% [markdown]
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > The datasets we’re analyzing are derived from data collected through the decennial US census. The census is made compulsory for American households through Title 13, and non-respondents may be subject to fines or short-term incarceration. However, the federal government is required to maintain strict confidentiality through differential privacy.
#
#  - [ ] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
#  > Participant anonymity is protected for 72 years by differential privacy, where statistical noise is added to the data to interfere with attempts to reidentify respondents. It maintains enough randomness to obscure data origin without compromising the integrity of the collection. Census data is re-released without redaction of personal information after 72 years have passed.
#
#  - [ ] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [ ] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
#  > There is no mechanism in place to get individuals’ data removed from the Census. But personal information such as names, addresses, and contact information are removed from datasets before their information is added to the national database.
#
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
#  > The federal government appears to keep census records indefinitely. After 72 years, the unredacted data is made publicly available and kept that way for research and genealogical documentation.
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
#  >Each state sets its own standards of public education and curriculum requirements, so students in different states likely have different experiences. Also, a low reported household income or a poor credit score may not be an indicator of lived financial hardship. The data only allows us to speculate on the living situation rather than explicitly stating it.
#
#  - [ ] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#  - [ ] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  - [ ] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
#  >The datasets used to generate this analysis are publicly available and accessible.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
#  >It can be argued that financial disparities in this country are inherently discriminatory, given the nation’s history. The data observed is not race-specific, but the races of respondents are included.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
#  >Studies of this kind have been conducted across various demographics and in several other countries around the world. Adjusting for the local cost of living in each state will result in a model that is fairly generalizable.
#
#  - [ ] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
#  >The model is intended to identify possible correlations between a household’s degree of financial hardship and the children’s performance in school.
#
#  - [ ] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
#  >Users should not face retribution for displaying financial need or academic difficulties. This model is intended to identify need so financial support can be provided.
#
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [ ] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# * We expect that our members will communicate accurately, frequently, and respectfully with one another in order to keep a good workflow and environment. We will use Discord as our main platform of communication, and expect that any unexpected leaves or holds with our members to be informed to the rest of our group.
# * We expect that decisions will be made as a majority agreement with adjustments made to cater closer to everyone’s preferences. When some members are unavailable, the remaining members will decide on executive decisions as a smaller group.
# * We expect that all members of the project will contribute equally on different parts of it. When on  e has trouble with getting something done, they will reach out to the rest of us so we can provide assistance in figuring out how to complete the task.  If a member falls behind or is seen slacking off on doing what they are supposed to do, we will notify them to pick up the pace and make sure to increase their productivity quickly.

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 2/4  |  5:30 PM | Read and think about the COGS108 project proposal and get an idea of what to do. | Decide what research question we should ask; Find proper dataset and sources to use. |
# | 2/18  | 5:30 PM  | Review all data and and properly access which data will certainly be used. Conclude data Checkpint file.| Discussion analyzation methods and clear up any confusion with data. |
# | 2/25  | 6 PM  | Ensure >90% of data analysis is completed and start conducting a conclusion based on data at hand. | Reflect on what analysis suggested, discuss finalization steps and talk about video ideas/submission.  |
# | 3/4  | 5:30 PM  |  Review the project as a whole and ensure everything looks correct. | Touch on any topics/conclusions that may be unclear and ensure everyone is satisfied with the project. |
# | 3/10 | 5:00 PM | Adjust any last minute feedback and concerns within the group. | Discuss video/presentation understanding and ideas |
